# %%
import yfinance as yf
ticker = yf.Ticker("AAPL")

# %%
ticker.financials          # Income Statement (annual)
ticker.quarterly_financials

ticker.balance_sheet
ticker.quarterly_balance_sheet

ticker.cashflow
ticker.quarterly_cashflow
# Out:
#                                                   2025-09-30    2025-06-30  \
# Free Cash Flow                                  2.648600e+10  2.440500e+10
# Repurchase Of Capital Stock                    -2.013200e+10 -2.107500e+10
# Repayment Of Debt                              -1.185000e+09 -1.770000e+09
# Issuance Of Debt                                0.000000e+00           NaN
# Capital Expenditure                            -3.242000e+09 -3.462000e+09
# Income Tax Paid Supplemental Data               6.037000e+09  5.649000e+09
# End Cash Position                               3.593400e+10  3.626900e+10
# Beginning Cash Position                         3.626900e+10  2.816200e+10
# Changes In Cash                                -3.350000e+08  8.107000e+09
# Financing Cash Flow                            -2.747600e+10 -2.483300e+10
# Cash Flow From Continuing Financing Activities -2.747600e+10 -2.483300e+10
# ...

# %%
ticker.earnings            # annual
ticker.quarterly_earnings
# Out:
# C:\Users\alexv\AppData\Local\Programs\Python\Python313\Lib\site-packages\yfinance\scrapers\fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)

# %%
ticker.earnings_dates
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# ...

# %%
ticker.info["trailingPE"]
ticker.info["forwardPE"]
# Out:
# 28.341707

# %%
PE = Price / EPS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 PE = Price / EPS
#
# NameError: name 'Price' is not defined

# %%
ticker.dividends
ticker.splits
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
ticker.institutional_holders
ticker.major_holders
ticker.insider_transactions
# Out:
#     Shares      Value URL                                      Text  \
# 0     3750        0.0           Stock Gift at price 0.00 per share.
# 1     3752  1017655.0               Sale at price 271.23 per share.
# 2     4199  1038787.0      Sale at price 245.89 - 248.73 per share.
# 3    16457        NaN
# 4     7371        NaN
# ..     ...        ...  ..                                       ...
# 71    1852        NaN
# 72    1852        NaN
# 73    1852        NaN
# 74    1852        NaN
# 75    1852        NaN
#
#               Insider                 Position Transaction Start Date  \
# 0   ADAMS KATHERINE L          General Counsel             2025-11-12
# 1   KONDO CHRISTOPHER                  Officer             2025-11-07
# 2        PAREKH KEVAN  Chief Financial Officer             2025-10-16
# 3        PAREKH KEVAN  Chief Financial Officer             2025-10-15
# 4   KONDO CHRISTOPHER                  Officer             2025-10-15
# ...

# %%
ticker.options               # дати експірацій
ticker.option_chain(date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 ticker.options               # дати експірацій
# ----> 2 ticker.option_chain(date)
#
# NameError: name 'date' is not defined

# %%
SPY, QQQ, VIX (^VIX), TNX (^TNX)

# %%
ticker.news
# Out:
# [{'id': 'd1a7c000-5bf0-34b1-a213-eda51ce77a6e',
#   'content': {'id': 'd1a7c000-5bf0-34b1-a213-eda51ce77a6e',
#    'contentType': 'STORY',
#    'title': 'Apple CEO Tim Cook Could Buy 92,984 iPhone 17s With His 2025 Compensation',
#    'description': '',
#    'summary': "Apple Inc. (NASDAQ:AAPL) CEO Tim Cook was one of the highest-paid executives in 2024. The CEO saw a slight dip in his 2025 compensation, but still took home an impressive pay package despite Apple stock trailing several leading market indexes for the year. Tim Cook's 2025 Salary and Pay Compensation Cook, who has been CEO of Apple since 2011 when he took over for co-founder Steve Jobs, has helped usher Apple into a new era of growth and taken Apple stock to new milestones. A new filing from Appl",
#    'pubDate': '2026-01-12T02:31:08Z',
#    'displayTime': '2026-01-12T02:31:08Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
# ...
